# %%
from imageio import imread
import os
path = "C:\\Users\\PC\\Documents\\Bart"
image = imread(os.path.join(path, "opdracht", "machine_learning", "classificatie", "aanwezig", "20220207_123451.jpg"))
image.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\berto\Desktop\Machine Learning\MustiGit\machine_learning_musti\discover_data.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/berto/Desktop/Machine%20Learning/MustiGit/machine_learning_musti/discover_data.ipynb#ch0000000?line=0'>1</a> from imageio import imread
#       <a href='vscode-notebook-cell:/c%3A/Users/berto/Desktop/Machine%20Learning/MustiGit/machine_learning_musti/discover_data.ipynb#ch0000000?line=1'>2</a> import os
#       <a href='vscode-notebook-cell:/c%3A/Users/berto/Desktop/Machine%20Learning/MustiGit/machine_learning_musti/discover_data.ipynb#ch0000000?line=2'>3</a> path = "C:\\Users\\PC\\Documents\\Bart"
#
# ModuleNotFoundError: No module named 'imageio'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(image, cmap="binary")
plt.axis("off")
plt.show()

# %%
red = image[:,:,0]
plt.imshow(red, cmap="binary")
plt.axis("off")
plt.show()

# %%
red
# Out:
# Array([[125,  71, 116, ..., 255, 255, 255],
#        [102, 128, 137, ..., 255, 255, 255],
#        [101,  96,  82, ..., 255, 255, 255],
#        ...,
#        [148, 151, 149, ...,  55,  51,  49],
#        [150, 149, 147, ...,  52,  50,  49],
#        [143, 143, 147, ...,  50,  50,  50]], dtype=uint8)

# %%
green = image[:,:,1]
plt.imshow(green, cmap="binary")
plt.axis("off")
plt.show()

# %%
blue = image[:,:,2]
plt.imshow(blue, cmap="binary")
plt.axis("off")
plt.show()

# %%
red_line = red.reshape(-1)
red_line
green_line = green.reshape(-1)
green_line
blue_line = blue.reshape(-1)
blue_line
# Out:
# Array([125,  71, 116, ...,  50,  50,  50], dtype=uint8)

# %%
import numpy as np
import pandas as pd
np_red_line = np.array(red_line)
pd_red_line = pd.DataFrame(np_red_line, columns=['red'])
pd_red_line.describe()
# Out:
#                  red
# count  225280.000000
# mean      129.300328
# std        70.305449
# min         4.000000
# 25%        85.000000
# 50%       121.000000
# 75%       182.000000
# max       255.000000

# %%
np_green_line = np.array(green_line)
pd_green_line = pd.DataFrame(np_green_line, columns=['green'])
pd_green_line.describe()
# Out:
#                green
# count  225280.000000
# mean      129.300328
# std        70.305449
# min         4.000000
# 25%        85.000000
# 50%       121.000000
# 75%       182.000000
# max       255.000000

# %%
np_blue_line = np.array(blue_line)
pd_blue_line = pd.DataFrame(np_blue_line, columns=['blue'])
pd_blue_line.describe()
# Out:
#                 blue
# count  225280.000000
# mean      129.300328
# std        70.305449
# min         4.000000
# 25%        85.000000
# 50%       121.000000
# 75%       182.000000
# max       255.000000

# %%
def load_and_flatten_image(imagePath):
    image = imread(imagePath)
    image_single_channel = image[:,:,0]
    image_array = image_single_channel[-1]
    return image_array

# %%
toto = load_and_flatten_image(os.path.join(path, "opdracht", "machine_learning", "classificatie", "aanwezig", "20220207_123451.jpg"))
toto.dtype
# Out:
# dtype('uint8')
